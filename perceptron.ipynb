# %%
#import statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
# %matplotlib nbagg
#%matplotlib inline

# %%
data_file1 = pd.read_csv('datafile1.csv', header=None, sep=",")
data_file2 = pd.read_csv('datafile2.csv', header=None, sep=",")
data_file3 = pd.read_csv('datafile3.csv', header=None, sep=",")
data_file4 = pd.read_csv('datafile4.csv', header=None, sep=",")
data_file1.columns = ['x1', 'x2','y']
data_file2.columns = ['x1', 'x2','y']
data_file3.columns = ['x1', 'x2','y']
data_file4.columns = ['x1', 'x2','y']

# %%
plt.scatter(data_file4['x1'], data_file1['x2'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def predict(x,s):
    activation = np.dot(x,s.T)
    if(activation > 0):
        return 1
    else:
        return 0

# %%
def train(x,y):
    weights = np.random.random_sample([3])
    weights = np.mat(weights)
    epochs = 20
    l_rate = 0.01
    for x_row,y_row in zip(x,y):
        s = weights[-1]
        for i in range(epochs):              
            activation = predict(x_row,s)
            error = y_row[0]-activation
            s[0,0] = s[0,0] + (l_rate)*(error)*(x_row[0])
            s[0,1] = s[0,1] + (l_rate)*(error)*(x_row[1])
            s[0,2] = s[0,2] + (l_rate)*(error)          
            print('epoch = ',i,' w1 = ', weights[-1].item((0, 0)),' w2 = ', weights[-1].item((0, 1)),
                ' bias = ', weights[-1].item((0, 2)),' error = ',error)
            if(error == 0):
                break  
        print("\n")        
        weights = np.vstack([weights,s])
    weights = np.delete( weights , (0), axis=0)    
    return weights

# %%
def perceptron(data_file):
    data = data_file.copy()
    y_df  = pd.DataFrame(data_file['y'])
    data.drop(['y'],axis = 1,inplace = True)
    b = pd.Series(np.ones(data['x1'].size))
    data['b'] = b
    x = data.as_matrix()
    y = y_df.as_matrix()
    weights = train(x,y)
    return(weights)

# %%
w_matrix1 = perceptron(data_file1)
# Out:
# epoch =  0  w1 =  0.9828072638616465  w2 =  0.7248672250765574  bias =  0.11349099613148939  error =  0
#
#
# epoch =  0  w1 =  0.96597088515049  w2 =  0.7426902495944375  bias =  0.10349099613148939  error =  -1
# epoch =  1  w1 =  0.9491345064393335  w2 =  0.7605132741123176  bias =  0.0934909961314894  error =  -1
# epoch =  2  w1 =  0.932298127728177  w2 =  0.7783362986301977  bias =  0.0834909961314894  error =  -1
# epoch =  3  w1 =  0.9154617490170205  w2 =  0.7961593231480778  bias =  0.0734909961314894  error =  -1
# epoch =  4  w1 =  0.898625370305864  w2 =  0.8139823476659579  bias =  0.06349099613148941  error =  -1
# epoch =  5  w1 =  0.8817889915947075  w2 =  0.831805372183838  bias =  0.05349099613148941  error =  -1
# epoch =  6  w1 =  0.864952612883551  w2 =  0.8496283967017181  bias =  0.04349099613148941  error =  -1
# epoch =  7  w1 =  0.864952612883551  w2 =  0.8496283967017181  bias =  0.04349099613148941  error =  0
#
#
# ...

# %%
w_matrix2 = perceptron(data_file2)
# Out:
# epoch =  0  w1 =  0.15374349282091537  w2 =  0.013929403054649181  bias =  0.43205808075611496  error =  0
#
#
# epoch =  0  w1 =  0.1707509498565978  w2 =  0.027313269997475978  bias =  0.42205808075611495  error =  -1
# epoch =  1  w1 =  0.18775840689228024  w2 =  0.040697136940302775  bias =  0.41205808075611494  error =  -1
# epoch =  2  w1 =  0.20476586392796267  w2 =  0.05408100388312957  bias =  0.40205808075611493  error =  -1
# epoch =  3  w1 =  0.20476586392796267  w2 =  0.05408100388312957  bias =  0.40205808075611493  error =  0
#
#
# epoch =  0  w1 =  0.224257196658264  w2 =  0.053089996322481604  bias =  0.3920580807561149  error =  -1
# epoch =  1  w1 =  0.224257196658264  w2 =  0.053089996322481604  bias =  0.3920580807561149  error =  0
#
#
# epoch =  0  w1 =  0.224257196658264  w2 =  0.053089996322481604  bias =  0.3920580807561149  error =  0
#
#
# epoch =  0  w1 =  0.21656920501537943  w2 =  0.058927078371406934  bias =  0.3820580807561149  error =  -1
# ...

# %%
w_matrix3 = perceptron(data_file3)
# Out:
# epoch =  0  w1 =  0.7627860035471911  w2 =  0.6357843330026823  bias =  0.13065688163638733  error =  -1
# epoch =  1  w1 =  0.7661435292919873  w2 =  0.6180623054087894  bias =  0.12065688163638734  error =  -1
# epoch =  2  w1 =  0.7695010550367835  w2 =  0.6003402778148964  bias =  0.11065688163638734  error =  -1
# epoch =  3  w1 =  0.7728585807815797  w2 =  0.5826182502210034  bias =  0.10065688163638735  error =  -1
# epoch =  4  w1 =  0.7762161065263758  w2 =  0.5648962226271105  bias =  0.09065688163638735  error =  -1
# epoch =  5  w1 =  0.779573632271172  w2 =  0.5471741950332175  bias =  0.08065688163638736  error =  -1
# epoch =  6  w1 =  0.7829311580159682  w2 =  0.5294521674393246  bias =  0.07065688163638736  error =  -1
# epoch =  7  w1 =  0.7862886837607644  w2 =  0.5117301398454316  bias =  0.06065688163638736  error =  -1
# epoch =  8  w1 =  0.7896462095055606  w2 =  0.4940081122515387  bias =  0.05065688163638736  error =  -1
# ...

# %%
w_matrix4 = perceptron(data_file4)
# Out:
# epoch =  0  w1 =  0.8748206933325656  w2 =  0.1783863075054083  bias =  0.17630713755493788  error =  0
#
#
# epoch =  0  w1 =  0.8604778885213674  w2 =  0.17226088936281447  bias =  0.18630713755493788  error =  1
# epoch =  1  w1 =  0.8461350837101692  w2 =  0.16613547122022065  bias =  0.1963071375549379  error =  1
# epoch =  2  w1 =  0.831792278898971  w2 =  0.16001005307762683  bias =  0.2063071375549379  error =  1
# epoch =  3  w1 =  0.8174494740877728  w2 =  0.15388463493503302  bias =  0.2163071375549379  error =  1
# epoch =  4  w1 =  0.8031066692765746  w2 =  0.1477592167924392  bias =  0.22630713755493792  error =  1
# epoch =  5  w1 =  0.7887638644653764  w2 =  0.14163379864984538  bias =  0.23630713755493793  error =  1
# epoch =  6  w1 =  0.7744210596541782  w2 =  0.13550838050725156  bias =  0.24630713755493794  error =  1
# epoch =  7  w1 =  0.76007825484298  w2 =  0.12938296236465774  bias =  0.25630713755493795  error =  1
# ...

# %%
#animated plot for data_file1
fig = plt.figure()
ax = plt.axes(xlim=(-2, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

ax.scatter(data_file1['x1'], data_file1['x2'], c = data_file1['y'])
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

def animate(i):
    x = data_file1['x1']
    y = -(w_matrix1[i,2]/w_matrix1[i,1]) -((w_matrix1[i,0]*x)/w_matrix1[i,1])
    line.set_data(x, y)
    return line,


# call the animator.  blit=True means only re-draw the parts that have changed.
ani = animation.FuncAnimation(fig, animate, init_func=init, frames=len(w_matrix1), interval=100, blit=True,repeat = False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#animated plot for data_file2
fig = plt.figure()
ax = plt.axes(xlim=(-2, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

ax.scatter(data_file2['x1'], data_file2['x2'], c = data_file2['y'])
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

def animate(i):
    x = data_file2['x1']
    y = -(w_matrix2[i,2]/w_matrix2[i,1]) -((w_matrix2[i,0]*x)/w_matrix2[i,1])
    line.set_data(x, y)
    return line,


# call the animator.  blit=True means only re-draw the parts that have changed.
ani = animation.FuncAnimation(fig, animate, init_func=init, frames=len(w_matrix2), interval=100, blit=True,repeat = False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#animated plot for data_file3
fig = plt.figure()
ax = plt.axes(xlim=(-2, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

ax.scatter(data_file3['x1'], data_file3['x2'], c = data_file3['y'])
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

def animate(i):
    x = data_file3['x1']
    y = -(w_matrix3[i,2]/w_matrix3[i,1]) -((w_matrix3[i,0]*x)/w_matrix3[i,1])
    line.set_data(x, y)
    return line,


# call the animator.  blit=True means only re-draw the parts that have changed.
ani = animation.FuncAnimation(fig, animate, init_func=init, frames=len(w_matrix3), interval=100, blit=True,repeat = False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#animated plot for data_file4
fig = plt.figure()
ax = plt.axes(xlim=(-2, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

ax.scatter(data_file4['x1'], data_file4['x2'], c = data_file4['y'])
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

def animate(i):
    x = data_file4['x1']
    y = -(w_matrix4[i,2]/w_matrix4[i,1]) -((w_matrix4[i,0]*x)/w_matrix4[i,1])
    line.set_data(x, y)
    return line,


# call the animator.  blit=True means only re-draw the parts that have changed.
ani = animation.FuncAnimation(fig, animate, init_func=init, frames=len(w_matrix4), interval=100, blit=True,repeat = False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
